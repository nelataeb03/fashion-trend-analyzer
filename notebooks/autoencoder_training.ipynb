# %%
# %pip install git+https://github.com/facebookresearch/segment-anything.git
# %pip install -q jupyter_bbox_widget roboflow dataclasses-json supervision
# %pip install ultralytics
# %wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Out:
# DEPRECATION: Loading egg at /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages/mmfashion-0.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting git+https://github.com/facebookresearch/segment-anything.git
#   Cloning https://github.com/facebookresearch/segment-anything.git to /private/var/folders/gm/7gv0mtdn65n5y8_gv6x4vgdm0000gn/T/pip-req-build-ghampvab
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /private/var/folders/gm/7gv0mtdn65n5y8_gv6x4vgdm0000gn/T/pip-req-build-ghampvab
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Preparing metadata (setup.py) ... done
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages/mmfashion-0.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages/mmfashion-0.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: ultralytics in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (8.2.74)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (3.9.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (1.14.0)
# Requirement already satisfied: torch>=1.8.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (4.65.2)
# Requirement already satisfied: psutil in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from ultralytics) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Requirement already satisfied: filelock in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: networkx in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nela/Downloads/fashion-trend-analyzer/venv/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%wget` not found.

# %%
import pandas as pd 
import numpy as np 
import os 
import cv2
import matplotlib.pyplot as plt
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Dense, BatchNormalization, Flatten, Reshape, Dropout, Activation, Concatenate, Add
from tensorflow.keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.layers import Add, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import ModelCheckpoint
import os
import cv2
import numpy as np
import torch
from segment_anything import sam_model_registry, SamPredictor
from ultralytics import YOLO
import supervision as sv

# %%
def convert_bbox_x1y1x2y2_to_xywh(x1, y1, x2, y2):
    """
    Function to convert bounding box coordinates from top-left and bottom-right
    points to top-left point with width and height.
    
    Args:
        x1, y1, x2, y2 (int): Bounding box coordinates.
        
    Returns:
        x, y, w, h (int): Converted bounding box coordinates.
    """
    w = x2 - x1
    h = y2 - y1
    x = x1
    y = y1
    return x, y, w, h


def get_device():
    """
    Function to get the current device (CPU or CUDA).
    
    Returns:
        device (torch.device): Current device.
    """
    return torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


def get_image_paths(image_dir):
    """
    Function to get all image paths in a directory.
    
    Args:
        image_dir (str): Path to the directory containing the images.
        
    Returns:
        image_paths (list): List of paths to the images.
    """
    image_paths = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith(".jpg")]
    return image_paths


def segment_image(yolo, mask_predictor, image_path):
    """
    Function to perform segmentation on an image.
    
    Args:
        yolo (YOLO): YOLO object for prediction.
        mask_predictor (SamPredictor): SAM model object for prediction.
        image_path (str): Path to the image to be segmented.
        
    Returns:
        None
    """
    yolo_output = yolo.predict(image_path, conf=0.5)

    r = []
    for result in yolo_output:
        for bbox in result.boxes.data,:
            box = bbox.int().cpu().numpy()
            for b in box:
                x, y, w, h = convert_bbox_x1y1x2y2_to_xywh(b[0], b[1], b[2], b[3])
                r.append([b[0], b[1], b[2], b[3], b[5]])

    # Create the image variable and box_annotator
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    mask_combined = np.zeros((image.shape[0], image.shape[1]), dtype=np.uint8)
    output = np.zeros_like(image)

    for i, box in enumerate(r):
        box = box[:-1]
        box = np.array(box)

        mask_predictor.set_image(image)
    
        masks, scores, logits = mask_predictor.predict(box=box, multimask_output=True)

        detections = sv.Detections(xyxy=sv.mask_to_xyxy(masks=masks), mask=masks)
        detections = detections[detections.area == np.max(detections.area)]

        # Combine the masks with a logical OR operation within the loop
        for m in masks:
            mask_combined = np.logical_or(mask_combined, m)
        
    # Use the combined mask to select the pixels of the original image
    output[mask_combined] = image[mask_combined]

    # Save the image with the original colors
    save_path = f"/content/drive/MyDrive/autoencoder_instagram/segmented_images/outfit_{os.path.basename(image_path).replace('.jpg', '.png')}"
    cv2.imwrite(save_path, cv2.cvtColor(output, cv2.COLOR_RGB2BGR))  # Convert back to BGR for saving


def main():
    """
    Main function to perform segmentation on all images in a directory.
    """
    MODEL_TYPE = "vit_h"
    CHECKPOINT_PATH = os.path.join(os.getcwd(), "../models", "sam_weights.pth")
    YOLO_WEIGHTS = "../models/yolo_weights.pt"
    IMAGE_DIR = "../images/original_images"
    
    # Make sure the segmented images directory exists
    if not os.path.exists("../images/segmented_images"):
        os.makedirs("../images/segmented_images")

    # Create the YOLO and SAM models
    yolo = YOLO(YOLO_WEIGHTS)
    sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=get_device())
    mask_predictor = SamPredictor(sam)
    
    # Segment all images in the directory
    image_paths = get_image_paths(IMAGE_DIR)
    for image_path in image_paths:
        # Define the path of the segmented image
        segmented_image_path = f"../images/segmented_images/outfit_{os.path.basename(image_path).replace('.jpg', '.png')}"
        
        # Check if the segmented image already exists
        if os.path.exists(segmented_image_path):
            print(f"Segmented image {segmented_image_path} already exists, skipping.")
            continue

        # If it doesn't exist, perform the segmentation
        segment_image(yolo, mask_predictor, image_path)


if __name__ == "__main__":
    main()
# Out:
# Segmented image ../images/segmented_images/outfit_63.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_823.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_189.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_77.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_837.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_638.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_604.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_162.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_176.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_88.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_610.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_348.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_360.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_406.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_412.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_599.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_228.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_214.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_572.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_566.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_200.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_758.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_770.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_764.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_765.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_771.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_759.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_567.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_201.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_215.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_573.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_229.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_598.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_413.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_375.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_361.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_407.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_349.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_177.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_611.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_89.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_605.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_163.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_639.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_188.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_836.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_76.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_822.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_62.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_74.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_834.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_60.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_820.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_48.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_808.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_149.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_613.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_175.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_161.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_607.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_388.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_439.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_377.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_411.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_405.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_363.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_559.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_203.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_565.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_571.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_217.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_798.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_767.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_773.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_772.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_766.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_799.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_570.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_216.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_202.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_564.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_558.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_404.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_362.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_376.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_410.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_438.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_389.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_160.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_606.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_612.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_174.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_148.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_809.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_49.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_821.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_61.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_835.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_75.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_59.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_819.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_71.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_831.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_65.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_825.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_170.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_616.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_602.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_164.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_158.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_399.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_414.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_372.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_366.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_400.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_428.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_560.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_206.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_212.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_574.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_548.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_789.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_762.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_776.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_777.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_763.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_788.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_549.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_213.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_575.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_561.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_207.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_429.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_367.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_401.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_415.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_373.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_398.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_159.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_603.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_165.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_171.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_617.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_824.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_64.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_830.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_70.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_818.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_58.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_8.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_198.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_66.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_826.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_72.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_832.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_167.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_601.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_99.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_615.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_173.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_629.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_403.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_365.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_371.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_417.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_359.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_588.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_577.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_211.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_205.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_563.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_239.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_775.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_761.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_749.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_748.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_774.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_238.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_204.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_562.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_576.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_210.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_589.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_358.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_370.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_416.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_402.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_364.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_628.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_614.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_172.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_166.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_98.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_600.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_833.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_73.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_199.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_827.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_67.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_9.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_698.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_840.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_14.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_854.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_28.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_868.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_883.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_897.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_129.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_101.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_667.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_673.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_115.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_459.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_465.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_303.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_317.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_471.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_288.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_539.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_511.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_277.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_263.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_713.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_707.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_706.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_712.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_262.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_504.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_510.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_276.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_538.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_289.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_316.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_470.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_464.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_302.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_458.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_672.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_114.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_100.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_666.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_896.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_128.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_882.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_869.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_29.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_855.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_15.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_841.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_699.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_17.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_857.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_843.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_894.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_880.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_658.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_116.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_670.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_664.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_102.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_499.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_328.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_472.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_314.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_300.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_466.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_248.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_506.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_260.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_274.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_512.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_738.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_704.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_710.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_711.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_705.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_739.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_275.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_513.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_507.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_261.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_301.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_467.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_473.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_315.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_329.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_498.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_665.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_103.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_117.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_671.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_659.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_881.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_895.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_842.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_856.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_16.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_852.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_846.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_675.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_113.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_107.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_661.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_891.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_649.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_885.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_488.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_311.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_477.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_463.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_305.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_339.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_265.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_503.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_517.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_271.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_259.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_701.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_715.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_729.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_728.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_714.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_700.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_258.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_516.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_270.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_264.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_502.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_338.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_462.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_304.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_310.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_476.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_489.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_884.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_648.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_890.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_106.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_660.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_674.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_112.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_847.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_853.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_13.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_39.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_879.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_845.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_689.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_11.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_851.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_662.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_104.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_110.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_676.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_886.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_138.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_892.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_306.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_460.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_474.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_312.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_448.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_299.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_272.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_514.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_500.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_266.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_528.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_716.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_702.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_703.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_717.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_529.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_501.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_267.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_273.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_515.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_298.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_449.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_475.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_313.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_307.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_461.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_893.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_887.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_139.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_111.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_677.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_663.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_105.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_850.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_10.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_688.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_844.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_878.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_38.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_21.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_861.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_35.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_875.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_685.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_691.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_108.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_120.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_646.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_652.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_134.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_487.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_493.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_478.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_444.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_322.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_336.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_450.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_295.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_281.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_518.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_530.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_256.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_242.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_524.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_901.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_732.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_726.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_727.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_733.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_900.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_243.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_525.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_531.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_257.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_519.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_280.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_294.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_337.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_451.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_445.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_323.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_479.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_492.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_486.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_653.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_135.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_121.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_647.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_109.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_848.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_690.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_684.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_874.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_34.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_860.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_20.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_36.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_876.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_22.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_862.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_692.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_686.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_679.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_137.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_889.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_651.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_645.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_123.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_490.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_484.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_309.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_453.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_335.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_321.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_447.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_282.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_296.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_269.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_527.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_241.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_255.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_533.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_902.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_719.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_725.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_731.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_730.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_724.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_718.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_903.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_254.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_532.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_526.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_240.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_268.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_297.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_283.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_320.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_446.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_452.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_334.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_308.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_485.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_491.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_644.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_122.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_136.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_650.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_888.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_678.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_687.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_693.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_863.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_23.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_877.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_37.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_697.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_683.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_33.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_873.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_27.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_867.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_654.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_132.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_126.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_898.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_640.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_668.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_495.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_481.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_330.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_456.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_442.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_324.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_318.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_287.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_293.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_244.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_522.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_536.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_250.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_278.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_720.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_734.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_708.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_709.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_735.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_721.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_906.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_279.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_537.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_251.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_245.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_523.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_292.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_286.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_319.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_443.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_325.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_331.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_457.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_480.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_494.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_669.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_127.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_641.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_899.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_655.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_133.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_866.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_26.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_872.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_32.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_682.png already exists, skipping.
# ...
# Segmented image ../images/segmented_images/outfit_197.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_183.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_96.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_168.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_82.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_632.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_154.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_140.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_626.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_395.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_381.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_418.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_356.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_430.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_424.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_342.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_587.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_593.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_578.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_222.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_544.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_550.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_236.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_785.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_791.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_746.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_752.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_753.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_747.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_790.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_784.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_551.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_237.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_223.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_545.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_579.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_592.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_586.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_425.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_343.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_357.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_431.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_419.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_380.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_394.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_627.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_633.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_155.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_83.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_97.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_169.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_182.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_828.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_68.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_196.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_800.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_40.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_814.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_54.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_6.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_192.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_78.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_838.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_186.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_2.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_50.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_810.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_44.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_804.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_151.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_637.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_623.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_145.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_93.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_87.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_179.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_390.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_384.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_435.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_353.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_347.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_421.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_409.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_582.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_596.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_541.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_227.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_233.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_555.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_569.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_780.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_794.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_743.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_757.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_756.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_742.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_795.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_781.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_568.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_232.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_554.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_540.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_226.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_597.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_583.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_408.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_346.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_420.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_434.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_352.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_385.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_391.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_86.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_178.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_92.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_622.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_144.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_150.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_636.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_805.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_45.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_3.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_811.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_839.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_79.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_187.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_193.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_185.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_191.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_47.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_807.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_53.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_813.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_1.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_146.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_620.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_634.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_152.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_84.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_608.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_90.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_387.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_422.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_344.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_436.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_378.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_595.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_581.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_556.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_230.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_224.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_542.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_218.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_797.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_783.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_754.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_740.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_768.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_769.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_741.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_755.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_782.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_796.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_219.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_225.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_543.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_557.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_231.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_580.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_594.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_379.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_351.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_437.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_423.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_345.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_392.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_386.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_91.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_609.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_85.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_635.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_153.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_147.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_621.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_812.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_52.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_806.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_46.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_190.png already exists, skipping.
# Segmented image ../images/segmented_images/outfit_184.png already exists, skipping.

# %%
def create_model():
    input_img = Input(shape=(256, 256, 3))

    # Encoder
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Dropout(0.2)(x) # Dropout layer
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Dropout(0.2)(x) # Dropout layer
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)
    x = Dropout(0.2)(x) # Dropout layer
    x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)
    encoded = Dropout(0.2)(x) # Dropout layer

    # Decoder
    x = Conv2D(16, (3, 3), activation='relu', padding='same')(encoded)
    x = BatchNormalization()(x)
    x = UpSampling2D((2, 2))(x)
    x = Dropout(0.2)(x) # Dropout layer
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = UpSampling2D((2, 2))(x)
    x = Dropout(0.2)(x) # Dropout layer
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = UpSampling2D((2, 2))(x)
    x = Dropout(0.2)(x) # Dropout layer
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x) # Added padding='same'
    x = BatchNormalization()(x)
    x = UpSampling2D((2, 2))(x)
    decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

    opt = Adam(learning_rate=0.0001)
    autoencoder = Model(input_img, decoded)
    autoencoder.compile(optimizer=opt, loss='mean_squared_error')
    
    return autoencoder

autoencoder = create_model()

# %%
# Create a list to store images
image_list = []

# specify your path
dir_path = "../images/segmented_images"

# Iterate over all files in the directory
for filename in os.listdir(dir_path):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Create the full image path
        img_path = os.path.join(dir_path, filename)
        # Read the image
        img = cv2.imread(img_path)
        # Convert the image to RGB
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        # Resize the image
        img = cv2.resize(img, (256, 256))
        # Normalize the image
        img = img / 255.0
        # Append the image to the list
        image_list.append(img)

# Convert the list to numpy array
X_train = np.array(image_list, dtype=np.float32)

# As an autoencoder, our target data is also our input data
y_train = X_train

# %%
# Save the model after every epoch
checkpoint_filepath = 'best_model.weights.h5'  # or '.hdf5'

# Save the model with the best validation loss
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,  # change this to False if you want to save the whole model
    monitor='val_loss',
    mode='min',
    save_best_only=True)

# Model fitting
history = autoencoder.fit(
    X_train, 
    y_train, 
    epochs=30, 
    batch_size=16, 
    validation_split=0.2, 
    callbacks=[model_checkpoint_callback]
)

# After training you can load the best weights back
autoencoder.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - loss: 0.2157 - val_loss: 0.1139
# Epoch 2/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - loss: 0.0897 - val_loss: 0.0387
# Epoch 3/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0519 - val_loss: 0.0206
# Epoch 4/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0379 - val_loss: 0.0159
# Epoch 5/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0277 - val_loss: 0.0150
# Epoch 6/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0242 - val_loss: 0.0143
# Epoch 7/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0216 - val_loss: 0.0143
# Epoch 8/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0186 - val_loss: 0.0140
# Epoch 9/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0175 - val_loss: 0.0128
# Epoch 10/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0156 - val_loss: 0.0129
# Epoch 11/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0144 - val_loss: 0.0123
# Epoch 12/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0142 - val_loss: 0.0108
# Epoch 13/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0129 - val_loss: 0.0102
# Epoch 14/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - loss: 0.0130 - val_loss: 0.0101
# Epoch 15/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - loss: 0.0123 - val_loss: 0.0096
# Epoch 16/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - loss: 0.0110 - val_loss: 0.0091
# Epoch 17/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 505s 11s/step - loss: 0.0103 - val_loss: 0.0092
# Epoch 18/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 119s 3s/step - loss: 0.0103 - val_loss: 0.0086
# Epoch 19/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - loss: 0.0096 - val_loss: 0.0081
# Epoch 20/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0088 - val_loss: 0.0079
# Epoch 21/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - loss: 0.0088 - val_loss: 0.0073
# Epoch 22/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0086 - val_loss: 0.0068
# Epoch 23/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0086 - val_loss: 0.0068
# Epoch 24/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0090 - val_loss: 0.0067
# Epoch 25/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - loss: 0.0078 - val_loss: 0.0069
# Epoch 26/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - loss: 0.0081 - val_loss: 0.0065
# Epoch 27/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - loss: 0.0078 - val_loss: 0.0062
# Epoch 28/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0070 - val_loss: 0.0063
# Epoch 29/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0078 - val_loss: 0.0068
# Epoch 30/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - loss: 0.0069 - val_loss: 0.0059

# %%
selected_indexes = [0, 3, 17, 20, 27, 29, 30, 33, 36, 40, 44, 52]  # List of selected indexes for displaying

fig, axs = plt.subplots(len(selected_indexes), 2, figsize=(20, 50))  # Adjust the figsize parameters to make images larger

for i, idx in enumerate(selected_indexes):
    img = image_list[idx]
    img = np.expand_dims(img, axis=0)  # Add the batch size dimension
    reconstructed_img = autoencoder.predict(img)

    # Reshape and rescale the images for display
    original_img = img.reshape((256, 256, 3))
    reconstructed_img = reconstructed_img.reshape((256, 256, 3))

    # Display original image
    axs[i, 0].imshow(original_img)
    axs[i, 0].set_title("Original Image {}".format(idx))
    axs[i, 0].axis('off')

    # Display reconstructed image
    axs[i, 1].imshow(reconstructed_img)
    axs[i, 1].set_title("Reconstructed Image {}".format(idx))
    axs[i, 1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss') 
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
autoencoder.save('../models/autoencoder.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
